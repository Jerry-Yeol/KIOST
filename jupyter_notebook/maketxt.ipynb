# %%
import os
import sys

# %%
KIOST_dir = '/home/jerry/Downloads/notebook/KIOST/'

#test = next(os.walk(KIOST_dir+'test'))[2]
#testannot = next(os.walk(MRI_dir+'testannot'))[2]
train = next(os.walk(KIOST_dir+'train2'))[2]
trainannot = next(os.walk(KIOST_dir+'trainannot'))[2]

#test.sort()
#testannot.sort()
train.sort()
trainannot.sort()

# %%
#print test[159]

#print testannot[159]

print train[-1]

print trainannot[-1]
# Out:
# red16641.jpg
# red16641.jpg

# %%
"""
with open('/home/jerry/Downloads/notebook/KIOST/test.txt', 'w') as f:
    for i in range(160):
        f.write('/home/jerry/Downloads/notebook/KIOST/test/{0}\n/home/jerry/Downloads/notebook/KIOST/testannot/{1}\n'.format(test[i], testannot[i]))
        print ('/home/jerry/Downloads/notebook/KIOST/test/{0}\n/home/jerry/Downloads/notebook/KIOST/testannot/{1}\n'.format(test[i], testannot[i]))
"""
with open('/home/jerry/Downloads/notebook/KIOST/train.txt', 'w') as f:
    for i in range(len(train)):
        f.write('/home/jerry/Downloads/notebook/KIOST/train2/{0}\n/home/jerry/Downloads/notebook/KIOST/trainannot/{1}\n'.format(train[i], trainannot[i]))
        print ('/home/jerry/Downloads/notebook/KIOST/train2/{0}\n/home/jerry/Downloads/notebook/KIOST/trainannot/{0}\n'.format(train[i], trainannot[i]))
# Out:
# /home/jerry/Downloads/notebook/KIOST/train2/red00001.jpg
# /home/jerry/Downloads/notebook/KIOST/trainannot/red00001.jpg
#
# /home/jerry/Downloads/notebook/KIOST/train2/red00002.jpg
# /home/jerry/Downloads/notebook/KIOST/trainannot/red00002.jpg
#
# /home/jerry/Downloads/notebook/KIOST/train2/red00003.jpg
# /home/jerry/Downloads/notebook/KIOST/trainannot/red00003.jpg
#
# /home/jerry/Downloads/notebook/KIOST/train2/red00004.jpg
# /home/jerry/Downloads/notebook/KIOST/trainannot/red00004.jpg
#
# /home/jerry/Downloads/notebook/KIOST/train2/red00005.jpg
# /home/jerry/Downloads/notebook/KIOST/trainannot/red00005.jpg
#
# /home/jerry/Downloads/notebook/KIOST/train2/red00006.jpg
# /home/jerry/Downloads/notebook/KIOST/trainannot/red00006.jpg
#
# /home/jerry/Downloads/notebook/KIOST/train2/red00007.jpg
# /home/jerry/Downloads/notebook/KIOST/trainannot/red00007.jpg
#
# /home/jerry/Downloads/notebook/KIOST/train2/red00008.jpg
# /home/jerry/Downloads/notebook/KIOST/trainannot/red00008.jpg
#
# ...
